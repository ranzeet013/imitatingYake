# %%
# prompt: mount drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install bs4

# %%
pip install jellyfish

# %%
pip install python-Levenshtein
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 39.2 MB/s eta 0:00:00
# ...

# %%
pip install datarepresentation
# Out:
# ERROR: Could not find a version that satisfies the requirement datarepresentation (from versions: none)
# ERROR: No matching distribution found for datarepresentation

# %%
file_path = "/content/drive/MyDrive/entityExtractions/pg75577-images.html"

with open(file_path, "r", encoding="utf-8") as file:
    html_content = file.read()

print(html_content[:1000])
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta charset="utf-8"><style>
# #pg-header div, #pg-footer div {
#     all: initial;
#     display: block;
#     margin-top: 1em;
#     margin-bottom: 1em;
#     margin-left: 2em;
# }
# #pg-footer div.agate {
#     font-size: 90%;
#     margin-top: 0;
#     margin-bottom: 0;
#     text-align: center;
# }
# #pg-footer li {
#     all: initial;
#     display: block;
#     margin-top: 1em;
#     margin-bottom: 1em;
#     text-indent: -0.6em;
# }
# #pg-footer div.secthead {
#     font-size: 110%;
#     font-weight: bold;
# }
# #pg-footer #project-gutenberg-license {
#     font-size: 110%;
#     margin-top: 0;
#     margin-bottom: 0;
#     text-align: center;
# }
# #pg-header-heading {
#     all: inherit;
#     text-align: center;
#     font-size: 120%;
#     font-weight:bold;
# }
# #pg-footer-heading {
#     all: inherit;
#     text-align: center;
#     font-size: 120%;
#     font-weight: normal;
#     margin-top: 0;
#     margin-bottom: 0;
# }
# ...

# %%
from bs4 import BeautifulSoup

file_path = "/content/drive/MyDrive/entityExtractions/pg75577-images.html"
with open(file_path, "r", encoding="utf-8") as file:
    html_content = file.read()

soup = BeautifulSoup(html_content, "html.parser")
chapter = soup.find("div", class_="chapter", id="ch01")

if chapter:
    print(chapter.get_text(separator="\n", strip=True))
else:
    print("Chapter not found in the HTML file.")
# Out:
# CHAPTER I
# I
# The heavy glass and bronze door revolved, and
# released from its sections, out of the grizzly
# November mist and into the rosy and fragrant hotel
# lobby, malice and envy, joy and enthusiasm, vanity
# and greed. Fear, masked with dignity, wrapped in
# sealskin and topped with a charming bright red hat,
# came quickly and alone.
# Two egg-shaped matrons glanced, lengthened and
# set their glances.
# Purple-and-henna breathed, “Beautiful wrap.”
# “I’ll tell you about her in a minute.”
# Brown-and-gold spoke from her throat.
# Their gazes followed the sealskin down the long strip
# of Mosul to the mahogany desk behind which a glossy
# clerk suddenly discovered reverence and added it to
# his attitude.
# “She’s one of the Quilters,” Brown-and-gold informed.
# “They are among the best-known families here
# in Oregon. They have an enormous ranch over east of
# the mountains in Quilter County; half of that country
# over there seems to be named for them. They’re
# ...

# %%
def custom_tokenizer(document):
    tokens = []
    for sentence in document.split('\n'):
        for word in sentence.split():
            tokens.append(word)
    return tokens

# %%
print(custom_tokenizer('truth about this woman, if she comes here. You see,'))
# Out:
# ['truth', 'about', 'this', 'woman,', 'if', 'she', 'comes', 'here.', 'You', 'see,']

# %%
print(word_tokenize('truth about this woman, if she comes here. You see'))
# Out:
# ['truth', 'about', 'this', 'woman', ',', 'if', 'she', 'comes', 'here', '.', 'You', 'see']

# %%
tokenizer = nltk.RegexpTokenizer(r'\w+')

# %%
print(tokenizer.tokenize('truth about this woman, if she comes here. You see'))
# Out:
# ['truth', 'about', 'this', 'woman', 'if', 'she', 'comes', 'here', 'You', 'see']

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import pickle
from collections import Counter

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
if chapter:
    chapter_text = chapter.get_text(separator="\n", strip=True).lower()
    print(chapter_text)
else:
    print("Chapter not found in the HTML file.")
# Out:
# chapter i
# i
# the heavy glass and bronze door revolved, and
# released from its sections, out of the grizzly
# november mist and into the rosy and fragrant hotel
# lobby, malice and envy, joy and enthusiasm, vanity
# and greed. fear, masked with dignity, wrapped in
# sealskin and topped with a charming bright red hat,
# came quickly and alone.
# two egg-shaped matrons glanced, lengthened and
# set their glances.
# purple-and-henna breathed, “beautiful wrap.”
# “i’ll tell you about her in a minute.”
# brown-and-gold spoke from her throat.
# their gazes followed the sealskin down the long strip
# of mosul to the mahogany desk behind which a glossy
# clerk suddenly discovered reverence and added it to
# his attitude.
# “she’s one of the quilters,” brown-and-gold informed.
# “they are among the best-known families here
# in oregon. they have an enormous ranch over east of
# the mountains in quilter county; half of that country
# over there seems to be named for them. they’re
# ...

# %%
tokens = tokenizer.tokenize(chapter_text)

# %%
print('The number of tokens are:', len(tokens))
print('The first 40 tokens are:', tokens[:40])
# Out:
# The number of tokens are: 7224
# The first 40 tokens are: ['chapter', 'i', 'i', 'the', 'heavy', 'glass', 'and', 'bronze', 'door', 'revolved', 'and', 'released', 'from', 'its', 'sections', 'out', 'of', 'the', 'grizzly', 'november', 'mist', 'and', 'into', 'the', 'rosy', 'and', 'fragrant', 'hotel', 'lobby', 'malice', 'and', 'envy', 'joy', 'and', 'enthusiasm', 'vanity', 'and', 'greed', 'fear', 'masked']

# %%
stopwords_en = stopwords.words('english')

# %%
print('The provided stopwords are: ', stopwords_en[:20])
# Out:
# The provided stopwords are:  ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been']

# %%
print('TNLTK stopwords are: :', len(stopwords_en))
# Out:
# TNLTK stopwords are: : 198

# %%
stopwords_en = set(stopwords_en)
print('i' in stopwords_en)
# Out:
# True

# %%
stop_words_removed_tokens = [token for token in tokens if token not in stopwords_en]
print('The number of tokens after removing stopwords:', len(stop_words_removed_tokens))
print('First 20 tokens:', stop_words_removed_tokens[:20])
# Out:
# The number of tokens after removing stopwords: 3177
# First 20 tokens: ['chapter', 'heavy', 'glass', 'bronze', 'door', 'revolved', 'released', 'sections', 'grizzly', 'november', 'mist', 'rosy', 'fragrant', 'hotel', 'lobby', 'malice', 'envy', 'joy', 'enthusiasm', 'vanity']

# %%
print('First 30 tokens (with stopwords)', tokens[:30], '\n')
print('First 30 tokens (without stopwords)', stop_words_removed_tokens[:30])
# Out:
# First 30 tokens (with stopwords) ['chapter', 'i', 'i', 'the', 'heavy', 'glass', 'and', 'bronze', 'door', 'revolved', 'and', 'released', 'from', 'its', 'sections', 'out', 'of', 'the', 'grizzly', 'november', 'mist', 'and', 'into', 'the', 'rosy', 'and', 'fragrant', 'hotel', 'lobby', 'malice']
#
# First 30 tokens (without stopwords) ['chapter', 'heavy', 'glass', 'bronze', 'door', 'revolved', 'released', 'sections', 'grizzly', 'november', 'mist', 'rosy', 'fragrant', 'hotel', 'lobby', 'malice', 'envy', 'joy', 'enthusiasm', 'vanity', 'greed', 'fear', 'masked', 'dignity', 'wrapped', 'sealskin', 'topped', 'charming', 'bright', 'red']

# %%
print(tokenize('ago; it was given for the blind. Quilters are supposed to'))
# Out:
# ['ago', 'given', 'blind', 'quilters', 'supposed']

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from bs4 import BeautifulSoup

nltk.download('stopwords')
stopwords_en = set(stopwords.words('english'))

def tokenize(document):
    document = document.lower()
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = [token for token in tokenizer.tokenize(document) if token not in stopwords_en]
    return tokens

def tokenize_html_file(file_path):
    with open(file_path, "r", encoding="utf-8") as file:
        html_content = file.read()

    soup = BeautifulSoup(html_content, "html.parser")
    chapter = soup.find("div", class_="chapter", id="ch01")
    if chapter:
        chapter_text = chapter.get_text(separator="\n", strip=True).lower()
        return tokenize(chapter_text)
    else:
        print("Chapter not found in the HTML file.")
        return []

file_path = "/content/drive/MyDrive/entityExtractions/pg75577-images.html"

tokens = tokenize_html_file(file_path)
print(tokens)
# Out:
# ['chapter', 'heavy', 'glass', 'bronze', 'door', 'revolved', 'released', 'sections', 'grizzly', 'november', 'mist', 'rosy', 'fragrant', 'hotel', 'lobby', 'malice', 'envy', 'joy', 'enthusiasm', 'vanity', 'greed', 'fear', 'masked', 'dignity', 'wrapped', 'sealskin', 'topped', 'charming', 'bright', 'red', 'hat', 'came', 'quickly', 'alone', 'two', 'egg', 'shaped', 'matrons', 'glanced', 'lengthened', 'set', 'glances', 'purple', 'henna', 'breathed', 'beautiful', 'wrap', 'tell', 'minute', 'brown', 'gold', 'spoke', 'throat', 'gazes', 'followed', 'sealskin', 'long', 'strip', 'mosul', 'mahogany', 'desk', 'behind', 'glossy', 'clerk', 'suddenly', 'discovered', 'reverence', 'added', 'attitude', 'one', 'quilters', 'brown', 'gold', 'informed', 'among', 'best', 'known', 'families', 'oregon', 'enormous', 'ranch', 'east', 'mountains', 'quilter', 'county', 'half', 'country', 'seems', 'named', 'millionaires', 'ken', 'says', 'everything', 'touch', 'turns', 'money', 'never', 'met', 'exactly', 'speak', 'tea'
# ...

# %%
print(len(tokens))
# Out:
# 3177

# %%
import pickle

pickle_file_path = "/content/drive/MyDrive/entityExtractions/chapter_tokens.p"

with open(pickle_file_path, "wb") as file:
    pickle.dump(tokens, file)

print(f"Tokens saved successfully to {pickle_file_path} ✅")
# Out:
# Tokens saved successfully to /content/drive/MyDrive/entityExtractions/chapter_tokens.p ✅

# %%
chapter_tokens = pickle.load(open('/content/drive/MyDrive/entityExtractions/stopWords/chapter_tokens.p', 'rb'))
unique_tokens = set(chapter_tokens)
frequency = Counter(chapter_tokens)

# %%
print(unique_tokens)
print(frequency)
# Out:
# {'flat', 'topped', 'impress', 'hideous', 'placed', 'surreptitious', 'satin', 'ouida', 'lad', 'engagement', 'new', 'common', 'haul', 'eight', 'understanding', 'saved', 'iii', 'earth', 'notice', 'drove', 'look', 'particular', 'destroyed', 'chains', 'interesting', 'door', 'open', 'stupid', 'mist', 'italy', 'another', 'spill', 'shockingly', 'judith', 'disabled', 'kid', 'told', 'grandfather', 'giving', 'dimming', 'irene', 'either', 'wait', 'waiting', 'tracking', 'delving', 'souls', 'cheap', 'whose', 'fool', 'room', 'well', 'extraordinary', 'glanced', 'lining', 'fall', 'identifying', 'trained', 'mistaught', 'merely', 'culprit', 'mystic', 'lately', 'proofs', 'contracted', 'steadily', 'excuse', 'oak', 'streaming', 'joy', 'ground', 'ten', 'sorry', 'seen', 'nice', 'suit', 'fussing', 'naïveté', 'none', 'uttered', 'note', 'chauffeur', 'henna', 'faculty', 'lean', 'specialist', 'frailty', 'snow', 'ursula', 'together', 'prettiest', 'lip', 'jude', 'bent', 'found', 'dear', 'studying', 'watson', 'want
# ...

# %%
stopwords_en.add('work')
stopwords_en.add('working')
stopwords_en.add('worked')
stopwords_en.add('intern')
stopwords_en.add('interning')
stopwords_en.add('interned')
stopwords_en.add('https')
stopwords_en.add('com')
stopwords_en.add('new')

# %%
import nltk
import pickle
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from bs4 import BeautifulSoup

nltk.download('stopwords')
stopwords_en = set(stopwords.words('english'))

def tokenize(document):
    document = document.lower()
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = [token for token in tokenizer.tokenize(document) if token not in stopwords_en]
    return tokens

def tokenize_html_file(file_path):
    with open(file_path, "r", encoding="utf-8") as file:
        html_content = file.read()

    soup = BeautifulSoup(html_content, "html.parser")
    chapter = soup.find("div", class_="chapter", id="ch01")

    if chapter:
        chapter_text = chapter.get_text(separator="\n", strip=True).lower()
        return tokenize(chapter_text)
    else:
        print("Chapter not found in the HTML file.")
        return []

def load_pickle_file(pickle_file_path):
    try:
        with open(pickle_file_path, "rb") as file:
            data = pickle.load(file)
        return data
    except FileNotFoundError:
        print(f"Pickle file {pickle_file_path} not found.")
        return []

html_file_path = "/content/drive/MyDrive/entityExtractions/pg75577-images.html"
pickle_file_path = "/content/drive/MyDrive/entityExtractions/stopWords/chapter_tokens.p"

html_tokens = tokenize_html_file(html_file_path)
print("HTML Tokens:", html_tokens[:50])

chapter_tokens = load_pickle_file(pickle_file_path)
print("Resume Tokens:", chapter_tokens[:50])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# HTML Tokens: ['chapter', 'heavy', 'glass', 'bronze', 'door', 'revolved', 'released', 'sections', 'grizzly', 'november', 'mist', 'rosy', 'fragrant', 'hotel', 'lobby', 'malice', 'envy', 'joy', 'enthusiasm', 'vanity', 'greed', 'fear', 'masked', 'dignity', 'wrapped', 'sealskin', 'topped', 'charming', 'bright', 'red', 'hat', 'came', 'quickly', 'alone', 'two', 'egg', 'shaped', 'matrons', 'glanced', 'lengthened', 'set', 'glances', 'purple', 'henna', 'breathed', 'beautiful', 'wrap', 'tell', 'minute', 'brown']
# ...

# %%
chapter_tokens = pickle.load(open('/content/drive/MyDrive/entityExtractions/stopWords/chapter_tokens.p', 'rb'))

unique_tokens = set(chapter_tokens)
frequency = Counter(chapter_tokens)

print('Total Number of Tokens:', len(chapter_tokens))
print('Number of Unique Tokens:', len(unique_tokens), '\n')
print('Frequency of 15 most common tokens: \n', frequency.most_common(15))
# Out:
# Total Number of Tokens: 3177
# Number of Unique Tokens: 1327
#
# Frequency of 15 most common tokens:
#  [('neal', 64), ('judy', 41), ('know', 39), ('think', 38), ('dr', 30), ('like', 27), ('look', 27), ('lucy', 27), ('joe', 24), ('years', 23), ('could', 23), ('well', 21), ('tell', 20), ('one', 20), ('say', 20)]

# %%
def tokenized_formatted(document):
    result = []
    for line in document.split('\n'):
        tokens = tokenize(line)
        result.append(' '.join(tokens))
    return '\n'.join(result)

pickle_file_path = '/content/drive/MyDrive/entityExtractions/stopWords/chapter_tokens.p'

try:
    chapter_tokens = pickle.load(open(pickle_file_path, 'rb'))
    chapter_tokenized_pretty = tokenized_formatted(' '.join(chapter_tokens))
    print(chapter_tokenized_pretty)

except FileNotFoundError:
    print(f"Error: Pickle file '{pickle_file_path}' not found.")
# Out:
# chapter heavy glass bronze door revolved released sections grizzly november mist rosy fragrant hotel lobby malice envy joy enthusiasm vanity greed fear masked dignity wrapped sealskin topped charming bright red hat came quickly alone two egg shaped matrons glanced lengthened set glances purple henna breathed beautiful wrap tell minute brown gold spoke throat gazes followed sealskin long strip mosul mahogany desk behind glossy clerk suddenly discovered reverence added attitude one quilters brown gold informed among best known families oregon enormous ranch east mountains quilter county half country seems named millionaires ken says everything touch turns money never met exactly speak tea two years ago given blind quilters supposed charitable told ken dollar mean thin dime us paused sigh live hotel lives ranch imagine anyone wanting live away things like ranch beautiful though quite show place bad leaving soon might motor see brother neal quilter stopping couple days suppose see seen t
# ...

# %%
pickle.dump(chapter_tokenized_pretty, open('/content/drive/MyDrive/entityExtractions/stopWords/chapter_tokenized.p', 'wb'))

# %%
file = pickle.load(open('/content/drive/MyDrive/entityExtractions/stopWords/chapter_tokenized.p', 'rb'))
print(file)
# Out:
# chapter heavy glass bronze door revolved released sections grizzly november mist rosy fragrant hotel lobby malice envy joy enthusiasm vanity greed fear masked dignity wrapped sealskin topped charming bright red hat came quickly alone two egg shaped matrons glanced lengthened set glances purple henna breathed beautiful wrap tell minute brown gold spoke throat gazes followed sealskin long strip mosul mahogany desk behind glossy clerk suddenly discovered reverence added attitude one quilters brown gold informed among best known families oregon enormous ranch east mountains quilter county half country seems named millionaires ken says everything touch turns money never met exactly speak tea two years ago given blind quilters supposed charitable told ken dollar mean thin dime us paused sigh live hotel lives ranch imagine anyone wanting live away things like ranch beautiful though quite show place bad leaving soon might motor see brother neal quilter stopping couple days suppose see seen t
# ...

# %%
import Levenshtein

# %%
ratio = Levenshtein.ratio("hello", "hallo")
print(f"Levenshtein ratio: {ratio}")

dist = Levenshtein.distance("hello", "hallo")
print(f"Levenshtein distance: {dist}")
# Out:
# Levenshtein ratio: 0.8
# Levenshtein distance: 1

# %%
html_tokens = tokenize_html_file(html_file_path)
print("HTML Tokens:", html_tokens[:50])
# Out:
# HTML Tokens: ['chapter', 'heavy', 'glass', 'bronze', 'door', 'revolved', 'released', 'sections', 'grizzly', 'november', 'mist', 'rosy', 'fragrant', 'hotel', 'lobby', 'malice', 'envy', 'joy', 'enthusiasm', 'vanity', 'greed', 'fear', 'masked', 'dignity', 'wrapped', 'sealskin', 'topped', 'charming', 'bright', 'red', 'hat', 'came', 'quickly', 'alone', 'two', 'egg', 'shaped', 'matrons', 'glanced', 'lengthened', 'set', 'glances', 'purple', 'henna', 'breathed', 'beautiful', 'wrap', 'tell', 'minute', 'brown']

# %%
from nltk.util import ngrams
from collections import Counter

def generate_candidates(tokens, n_max=3):
    candidates = []
    for n in range(1, n_max + 1):
        ngram_candidates = list(ngrams(tokens, n))
        candidates.extend([' '.join(ngram) for ngram in ngram_candidates])
    return candidates

# Example usage:
candidates = generate_candidates(html_tokens)
print(candidates)
# Out:
# ['chapter', 'heavy', 'glass', 'bronze', 'door', 'revolved', 'released', 'sections', 'grizzly', 'november', 'mist', 'rosy', 'fragrant', 'hotel', 'lobby', 'malice', 'envy', 'joy', 'enthusiasm', 'vanity', 'greed', 'fear', 'masked', 'dignity', 'wrapped', 'sealskin', 'topped', 'charming', 'bright', 'red', 'hat', 'came', 'quickly', 'alone', 'two', 'egg', 'shaped', 'matrons', 'glanced', 'lengthened', 'set', 'glances', 'purple', 'henna', 'breathed', 'beautiful', 'wrap', 'tell', 'minute', 'brown', 'gold', 'spoke', 'throat', 'gazes', 'followed', 'sealskin', 'long', 'strip', 'mosul', 'mahogany', 'desk', 'behind', 'glossy', 'clerk', 'suddenly', 'discovered', 'reverence', 'added', 'attitude', 'one', 'quilters', 'brown', 'gold', 'informed', 'among', 'best', 'known', 'families', 'oregon', 'enormous', 'ranch', 'east', 'mountains', 'quilter', 'county', 'half', 'country', 'seems', 'named', 'millionaires', 'ken', 'says', 'everything', 'touch', 'turns', 'money', 'never', 'met', 'exactly', 'speak', 'tea'
# ...

# %%
def casing_feature(keyword):
    return any(word[0].isupper() for word in keyword.split())

# %%
def word_position_feature(keyword, tokens):
    words = keyword.split()
    first_word_pos = tokens.index(words[0]) if words[0] in tokens else -1
    if first_word_pos == -1:
        return 0
    return 1 / (first_word_pos + 1)

# %%
def word_frequency_feature(keyword, tokens):
    count = tokens.count(keyword)
    return count / len(tokens)

# %%
def word_relatedness_feature(keyword, tokens, window_size=5):
    words = keyword.split()
    related_count = 0
    for i, word in enumerate(tokens):
        if word == words[0]:
            window = tokens[i+1:i+1+window_size]
            related_count += sum(1 for w in words[1:] if w in window)
    return related_count

# %%
def context_dispersion_feature(keyword, tokens, window_size=5):
    words = keyword.split()
    positions = [i for i, word in enumerate(tokens) if word == words[0]]
    dispersion_score = 0
    for pos in positions:
        window = tokens[pos:pos+window_size]
        dispersion_score += sum(1 for w in words[1:] if w in window)
    return dispersion_score / len(positions) if positions else 0

# %%
# 3. Scoring candidates based on features
def score_candidates(candidates, tokens):
    scored_candidates = []
    for candidate in candidates:
        f1 = casing_feature(candidate)
        f2 = word_position_feature(candidate, tokens)
        f3 = word_frequency_feature(candidate, tokens)
        f4 = word_relatedness_feature(candidate, tokens)
        f5 = context_dispersion_feature(candidate, tokens)

        score = f1 + f2 + f3 + f4 + f5
        scored_candidates.append((candidate, score))
    return scored_candidates

# %%
candidates = generate_candidates(html_tokens)
scored_candidates = score_candidates(candidates, html_tokens)

print(scored_candidates)
# Out:
# [('chapter', 1.0003147623544224), ('heavy', 0.5022688689711399), ('glass', 0.3336480956877557), ('bronze', 0.2503147623544224), ('door', 0.20286418388263203), ('revolved', 0.16698142902108906), ('released', 0.14317190521156525), ('sections', 0.1253147623544224), ('grizzly', 0.11142587346553351), ('november', 0.10031476235442241), ('mist', 0.09122385326351332), ('rosy', 0.08364809568775573), ('fragrant', 0.07723783927749933), ('hotel', 0.07444200681117336), ('lobby', 0.06698142902108907), ('malice', 0.0628147623544224), ('envy', 0.059138291766187116), ('joy', 0.055870317909977964), ('enthusiasm', 0.05294634130179083), ('vanity', 0.050314762354422414), ('greed', 0.04793380997347003), ('fear', 0.04687075323513218), ('masked', 0.04379302322398763), ('dignity', 0.041981429021089076), ('wrapped', 0.04031476235442241), ('sealskin', 0.07134912768651232), ('topped', 0.037351799391459446), ('charming', 0.036029048068708124), ('bright', 0.034797520975112066), ('red', 0.03570586715017382), ('hat
# ...

# %%
def rank_keywords_by_frequency(candidates, tokens):
    frequency = Counter(tokens)
    ranked_keywords = [(keyword, frequency[keyword]) for keyword in candidates]
    ranked_keywords = sorted(ranked_keywords, key=lambda x: x[1], reverse=True)
    return ranked_keywords

# %%
ranked_keywords = rank_keywords_by_frequency(candidates, html_tokens)
print(ranked_keywords)
# Out:
# [('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('neal', 64), ('judy', 41), ('judy', 41), ('judy', 41), ('judy', 41), ('judy', 41), ('judy', 41), ('judy', 41), ('j
# ...

# %%
# !pip freeze > requirements.txt

# %%
from google.colab import files
files.download('requirements.txt')
